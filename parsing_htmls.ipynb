# %%
from bs4 import BeautifulSoup
import json
import os

# %%
def parse_job_html(directory, file_path):
    
    full_path = os.path.join(directory, file_path)
    
    with open(full_path, 'r') as f:
        soup = BeautifulSoup(f.read(), 'html.parser')
    
    job_data = {}
    
    def get_field(soup, field_name):
       try:
           element = soup.find('span', string=field_name)
           if element:
               # cleaning addresses
               if field_name == 'Position Address: ':
                   addr_span = element.find_next('span', {'class': 'smallertext'})
                   return addr_span.text.split('\xa0')[0].strip().replace('\n', '').replace('\u2019', "'").replace('\u2022', '').replace('\t', '').replace('\u2013', '-')
               return element.next_sibling.text.strip().replace('\n', '').replace('\u2019', "'").replace('\u2022', '').replace('\t', '').replace('\u2013', '-')
           return "N/A"
       except:
           return "N/A"

    def get_description_field(soup, field_name):
       try:
           header = soup.find('span', string=field_name)
           if header:
               desc = header.find_next('span', {'class': 'smallertext'})
               if desc:
                   return desc.text.strip().capitalize().replace('\n', '').replace('\u2019', "'").replace('\u2022', '').replace('\t', '').replace('\u2013', '-')
           return "N/A"
       except:
           return "N/A"
    
    try:
        title = soup.find('span', {'class': 'largertext'}).text
        job_data['title'] = title
    except:
        job_data['title'] = "N/A"
    
    job_data['employer'] = get_field(soup, 'Employer: ')
    job_data['company_description'] = get_description_field(soup, 'Division/Location/Company Description:')
    job_data['position_description'] = get_description_field(soup, 'Position Description:')
    job_data['openings'] = get_field(soup, 'Number of Openings: ')
    job_data['qualifications'] = get_description_field(soup, 'Qualifications:')
    job_data['address'] = get_field(soup, 'Position Address: ')
    job_data['transportation'] = get_field(soup, 'Transportation to work: ')
    job_data['travel_required'] = get_field(soup, 'Travel required for position: ')
    job_data['compensation'] = get_field(soup, 'Compensation Status: ')
    job_data['min_gpa'] = get_field(soup, 'Minimum GPA: ').strip("-").strip()
    job_data['citizenship'] = get_field(soup, 'Citizenship Restriction: ')
    job_data['screening'] = get_field(soup, 'Pre-Employment Screening Requirements: ')
    
    return job_data

def process_all_files(directory):
    all_jobs = {}
    
    for filename in os.listdir(directory):
        if filename.endswith('.html'):
            try:
                print(f"Processing {filename}")
                job_data = parse_job_html(directory, filename)
                
                if job_data['title'] != "N/A":
                    job_id = job_data['title']
                else:
                    job_id = filename.replace('.html', '')
                    
                all_jobs[job_id] = job_data
                print(f"Successfully processed {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")
                continue

    with open('all_jobs.json', 'w', encoding='utf-8') as f:
        json.dump(all_jobs, f, indent=4)  
    
process_all_files('job_htmls/')
# Out:
# Processing job_17.html
# Successfully processed job_17.html
# Processing job_21.html
# Successfully processed job_21.html
# Processing job_3.html
# Successfully processed job_3.html
# Processing job_2.html
# Successfully processed job_2.html
# Processing job_20.html
# Successfully processed job_20.html
# Processing job_16.html
# Successfully processed job_16.html
# Processing job_27.html
# Successfully processed job_27.html
# Processing job_5.html
# Successfully processed job_5.html
# Processing job_9.html
# Successfully processed job_9.html
# Processing job_11.html
# Successfully processed job_11.html
# Processing job_10.html
# Successfully processed job_10.html
# Processing job_8.html
# Successfully processed job_8.html
# Processing job_4.html
# Successfully processed job_4.html
# Processing job_26.html
# Successfully processed job_26.html
# Processing job_30.html
# Successfully processed job_30.html
# Processing job_7.html
# Successfully processed job_7.html
# Processing job_25.html
# Successfully processed job_25.html
# Processing job_13.html
# Successfully processed job_13.html
# Processing job_29.html
# Successfully processed job_29.html
# Processing job_28.html
# Successfully processed job_28.html
# Processing job_12.html
# Successfully processed job_12.html
# Processing job_24.html
# Successfully processed job_24.html
# Processing job_6.html
# Successfully processed job_6.html
# Processing job_15.html
# Successfully processed job_15.html
# Processing job_19.html
# Successfully processed job_19.html
# Processing job_1.html
# Successfully processed job_1.html
# Processing job_23.html
# Successfully processed job_23.html
# Processing job_22.html
# Successfully processed job_22.html
# Processing job_18.html
# Successfully processed job_18.html
# Processing job_14.html
# Successfully processed job_14.html
